# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
file1 = pd.read_csv('file1.csv')

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2 = pd.read_csv('file2.csv')

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3 = pd.read_csv('file3.csv')

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
column_names = file3.columns

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (7070, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.describe
# Out:
# <bound method NDFrame.describe of      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2.describe
# Out:
# <bound method NDFrame.describe of      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
# ...

# %%
file3.describe
# Out:
# <bound method NDFrame.describe of      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
# ...

# %%
# very scrappy way of rearranging column headers
file1.rename(columns={ 'ST':'State','GENDER':'Customer Lifetime Value','Customer Lifetime Value':'Gender','Vehicle Class':'Total Claim Amount','Total Claim Amount':'Vehicle Class'})
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona                       F              Bachelor
# 2     AI49188      Nevada                       F              Bachelor
# 3     WW63253  California                       M              Bachelor
# 4     GA49547  Washington                       M  High School or Below
# ...       ...         ...                     ...                   ...
# 4003      NaN         NaN                     NaN                   NaN
# 4004      NaN         NaN                     NaN                   NaN
# 4005      NaN         NaN                     NaN                   NaN
# 4006      NaN         NaN                     NaN                   NaN
# 4007      NaN         NaN                     NaN                   NaN
#
#            Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
file2.rename(columns={ 'ST':'State','GENDER':'Customer Lifetime Value','Customer Lifetime Value':'Gender','Total Claim Amount':'Policy Type','Policy Type':'Total Claim Amount'})
# Out:
#      Customer       State        Gender             Education Gender  Income  \
# 0     SA25987  Washington   3479.137523  High School or Below      M       0
# 1     TB86706     Arizona   2502.637401                Master      M       0
# 2     ZL73902      Nevada   3265.156348              Bachelor      F   25820
# 3     KX23516  California   4455.843406  High School or Below      F       0
# 4     FN77294  California   7704.958480  High School or Below      M   30366
# ...       ...         ...           ...                   ...    ...     ...
# 7065  LA72316  California  23405.987980              Bachelor      M   71941
# 7066  PK87824  California   3096.511217               College      F   21604
# 7067  TD14365  California   8163.890428              Bachelor      M       0
# 7068  UP19263  California   7524.442436               College      M   21941
# 7069  Y167826  California   2611.836866               College      M       0
#
# ...

# %%
file2.rename(columns={'Total Claim Amount':'Policy Type','Policy Type':'Total Claim Amount'})
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file2.rename(columns={'Total Claim Amount':'Policy Type1'})
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file2.rename(columns={'Policy Type1':'Total Claim Amount'})
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
data = pd.DataFrame(columns=column_names)

# %%
print(data)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %%
#concatenate 3 files -- somehow gives me additional 2 columns as output??
data = pd.concat([data,file1,file2,file3],axis = 0)

# %%
data.head()
# Out:
#   Customer State Customer Lifetime Value             Education Gender  \
# 0  RB50392   NaN                     NaN                Master    NaN
# 1  QZ44356   NaN              697953.59%              Bachelor    NaN
# 2  AI49188   NaN             1288743.17%              Bachelor    NaN
# 3  WW63253   NaN              764586.18%              Bachelor    NaN
# 4  GA49547   NaN              536307.65%  High School or Below    NaN
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Total Claim Amount  Vehicle Class          ST GENDER
# ...

# %%
data.shape
# Out:
# (18148, 13)

# %%
new_col_names = []
for i in range(len(data.columns)):
    new_col_names.append(data.columns[i].lower())

# %%
print(new_col_names)
# Out:
# ['customer', 'state', 'customer lifetime value', 'education', 'gender', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'total claim amount', 'vehicle class', 'st', 'gender']

# %%
data.columns = new_col_names

# %%
#which columns are numerical
data._get_numeric_data()
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [18148 rows x 3 columns]

# %%
#which columns are categorical
type(data['customer', 'state', 'customer lifetime value', 'education', 'gender', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'total claim amount', 'vehicle class', 'st', 'gender'])
# Out:
# pandas.core.frame.DataFrame
